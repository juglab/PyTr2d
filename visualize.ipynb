# %%
from viz import load_tracklet_selection, plot_tracklet_selection

selection = load_tracklet_selection(
    dataset_root="/group/jug/Sheida/PyTr2d/data/Fluo-N2DL-HeLa_train/Fluo-N2DL-HeLa",
    track_sequence="toy_consensus",
    frames=[0, 1, 2],
    track_ids_by_view={
        "embedseg": [5],
        "stardist": [5],
        "joint": [5],
    },
)

fig = plot_tracklet_selection(selection)
